# %%
# Import basic libraries
import pandas as pd
import numpy as np
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import os 
from pathlib import Path
import sys
from tqdm import tqdm
import shap # Import the SHAP library
import wandb
import xgboost
from xgboost import XGBRegressor
import sklearn
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Define project root based on notebook location
def find_project_root(current: Path, marker: str = ".git"):
    for parent in current.resolve().parents:
        if (parent / marker).exists():
            return parent
    return current.resolve()  # fallback

PROJECT_ROOT = find_project_root(Path.cwd())
RAW_DIR = PROJECT_ROOT / "data" / "rawr"
INTERIM_DIR = PROJECT_ROOT / "data" / "interim"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
EXTERNAL_DIR = PROJECT_ROOT / "data" / "external"

# %% [markdown]
# Creating lag variables for machine learning (by region)

# %%
df = pd.read_csv(PROCESSED_DIR / "INDONESIA" /"monthly_dengue_env_region.csv")


# Define variables based on new names
env_vars = [
    'temperature_2m', 'temperature_2m_min', 'temperature_2m_max',
    'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index'
]

climate_vars = [
    'ANOM1+2','ANOM3','ANOM4',
    'ANOM3.4', 'DMI', 'DMI_East',
]

lulc_vars = ['Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30',
        'Class_20', 'Class_10', 'Class_90', 'Class_80']

target_var = 'Incidence_Rate'

# Sort by region and time
df = df.sort_values(['Region', 'YearMonth'])

# Create lag features
# Environmental: 1, 2, 3 month lags
for var in env_vars:
    for lag in [1, 2, 3]:
        df[f'{var}_lag{lag}'] = df.groupby('Region')[var].shift(lag)

# Climate indices: 1, 3, 6 month lags
for var in climate_vars:
    for lag in [1, 3, 6]:
        df[f'{var}_lag{lag}'] = df.groupby('Region')[var].shift(lag)

# Original features
feat_list = env_vars + climate_vars + lulc_vars

# Lag features for environmental variables (1, 2, 3 months)
for var in env_vars:
    for lag in [1, 2, 3]:
        feat_list.append(f'{var}_lag{lag}')

# Lag features for climate variables (1, 3, 6 months)
for var in climate_vars:
    for lag in [1, 3, 6]:
        feat_list.append(f'{var}_lag{lag}')

# %%
# --- Define the training function for a single run ---
# Pass df as an argument
def train(df, features_to_use=None): # Add features_to_use as an argument, with a default of None
    # wandb.init() will automatically pick up the config from the sweep controller
    # This creates a new run for each iteration of the sweep
    with wandb.init(project="dengue-indonesia-forecasting") as run:
        # Access hyperparameters from wandb.config
        config = run.config

        print(f"\n--- Starting run with config: {config} ---")

        # --- Load and Preprocess Data
        # Ensure 'YearMonth' is a datetime object and sort by it for time series processing
        # Important: Sort by YearMonth first, then Region to ensure consistent time ordering
        # before one-hot encoding, especially if data for different regions might not be perfectly aligned
        df['YearMonth'] = pd.to_datetime(df['YearMonth'])
        df = df.sort_values(by=['YearMonth', 'Region']).reset_index(drop=True)

        # --- Handle 'Region' column ---
        # If 'Region' is in features_to_use, it will be handled as a regular numerical feature
        # If not, it will be excluded from feature columns.
        # We are explicitly NOT one-hot encoding 'Region' based on your request.

        # Define your features (X) and target (y)
        target_column = 'Incidence_Rate'

        # Determine the feature columns
        if features_to_use is not None:
            # Use the specified list of features, ensuring 'Region' is excluded if it was implicitly included
            # Filter out 'YearMonth' and target_column if they were somehow included in features_to_use
            feature_columns = [col for col in features_to_use if col not in ['YearMonth', target_column, 'Region']]
        else:
            # Original behavior: use all columns except 'YearMonth' and 'Total_Infection' and 'Region'
            feature_columns = [col for col in df.columns if col not in ['YearMonth', target_column, 'Region']]
            
        # If 'Region' needs to be used as a numerical feature, ensure it's not removed by the above logic.
        # But based on your request "I don't want to use region as a training feature", it's excluded.
        
        print(f"Features selected for training: {feature_columns}")

        # Final check for NaNs after all preprocessing steps
        df_processed = df.dropna(subset=feature_columns + [target_column])

        # Walk-Forward Validation Setup (on the entire combined dataset)
        initial_train_months = config.initial_train_months # Get from config
        test_window = config.test_window # Get from config

        n_samples = len(df_processed)
        n_splits = (n_samples - initial_train_months) // test_window

        if n_splits <= 0:
            print("Not enough data for specified initial_train_months and test_window.")
            print(f"Total samples: {n_samples}, Initial train: {initial_train_months}, Test window: {test_window}")
            run.finish()
            return

        print(f"Performing {n_splits} walk-forward splits on combined data...")

        all_preds = []
        all_true = []
        fold_metrics = []
        
        # Lists to store SHAP values for aggregation or further analysis
        all_shap_values = []
        all_expected_values = []
        all_X_test_folds = [] # <--- NEW: Store X_test_fold for SHAP plotting

        for i in range(n_splits):
            train_end_idx = initial_train_months + i * test_window
            test_start_idx = train_end_idx
            test_end_idx = test_start_idx + test_window

            if test_end_idx > n_samples:
                print(f"    Warning: Test end index {test_end_idx} exceeds total samples {n_samples}. Ending walk-forward.")
                break # Stop if we run out of data for a full test window

            X_train_fold = df_processed.iloc[:train_end_idx][feature_columns]
            y_train_fold = df_processed.iloc[:train_end_idx][target_column]
            X_test_fold = df_processed.iloc[test_start_idx:test_end_idx][feature_columns]
            y_test_fold = df_processed.iloc[test_start_idx:test_end_idx][target_column]

            # --- Model Training ---
            model = xgboost.XGBRegressor(
                objective='reg:squarederror', tree_method="hist", device="cuda", # device="cuda" is key for GPU
                n_estimators=config.n_estimators,
                learning_rate=config.learning_rate,
                max_depth=config.max_depth,
                subsample=config.subsample,
                colsample_bytree=config.colsample_bytree,
                random_state=42,
                n_jobs=-1 # Use all available cores
            )

            model.fit(X_train_fold, y_train_fold)

            # --- Prediction ---
            predictions = model.predict(X_test_fold)
            predictions = np.maximum(0, predictions).astype(int)

            # --- Calculate SHAP values with GPU acceleration ---
            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X_test_fold)
            expected_value = explainer.expected_value
            
            all_shap_values.append(shap_values)
            all_expected_values.append(expected_value)
            all_X_test_folds.append(X_test_fold) # <--- NEW: Append the X_test_fold here

            # --- Evaluate and Log Fold Metrics ---
            fold_rmse = np.sqrt(mean_squared_error(y_test_fold, predictions))
            fold_mae = mean_absolute_error(y_test_fold, predictions)

            fold_metrics.append({'rmse': fold_rmse, 'mae': fold_mae})
            print(f"    Fold {i+1}/{n_splits}: RMSE={fold_rmse:.2f}, MAE={fold_mae:.2f}")
            # Log metrics for the *current* fold
            wandb.log({
                f"fold_{i+1}_rmse": fold_rmse, # Log RMSE for this specific fold
                f"fold_{i+1}_mae": fold_mae,   # Log MAE for this specific fold
                "current_fold": i + 1,       # Log the current fold number as a step
                "fold_rmse_history": fold_rmse, # Log general fold RMSE to see trend
                "fold_mae_history": fold_mae    # Log general fold MAE to see trend
            }, step=i+1) # Use step to track progress over folds
            all_preds.extend(predictions)
            all_true.extend(y_test_fold)

        # --- Calculate and Log Global Overall Metrics ---
        if all_true:
            global_overall_rmse = np.sqrt(mean_squared_error(all_true, all_preds))
            global_overall_mae = mean_absolute_error(all_true, all_preds)

            wandb.log({
                "global_overall_rmse": global_overall_rmse,
                "global_overall_mae": global_overall_mae,
                "mean_fold_rmse": np.mean([f['rmse'] for f in fold_metrics]),
                "mean_fold_mae": np.mean([f['mae'] for f in fold_metrics]),
                "n_splits": n_splits
            })

            print(f"\n--- GLOBAL Overall Walk-Forward Evaluation: RMSE={global_overall_rmse:.2f}, MAE={global_overall_mae:.2f} ---")
        else:
            print("\n--- No successful predictions made during walk-forward. ---")
            wandb.log({"global_overall_rmse": float('inf'), "global_overall_mae": float('inf')})
            
        # --- Aggregate and Log SHAP values (Optional, but useful) ---
        if all_shap_values and all_X_test_folds: # <--- Ensure both lists have data
            # Concatenate all SHAP values from folds for a global view
            concatenated_shap_values = np.vstack(all_shap_values)
            # <--- NEW: Concatenate all X_test_folds to get all feature values for plotting
            concatenated_X_test_folds = pd.concat(all_X_test_folds, axis=0) 
            
            # Save raw SHAP data and X_test for future aggregation
            np.save("shap_values.npy", concatenated_shap_values)
            concatenated_X_test_folds.to_csv("X_test_for_shap.csv", index=False)

            # Log as a W&B artifact
            artifact = wandb.Artifact("shap_data", type="dataset")
            artifact.add_file("shap_values.npy")
            artifact.add_file("X_test_for_shap.csv")
            run.log_artifact(artifact)

            try:
                # Pass the actual feature values for correct coloring
                # Ensure feature names are correctly aligned, usually by passing the DataFrame
                shap.summary_plot(concatenated_shap_values, concatenated_X_test_folds, show=False)
                wandb.log({"shap_summary_plot": wandb.Image(plt)}) # Log the plot
                plt.close() # Close the plot to prevent it from displaying in notebooks
            except Exception as e:
                print(f"Could not generate SHAP summary plot: {e}")

            # You can also log individual feature importances based on mean absolute SHAP values
            mean_abs_shap = np.mean(np.abs(concatenated_shap_values), axis=0)
            feature_importances_shap = pd.DataFrame({
                'feature': concatenated_X_test_folds.columns, # Use columns from the concatenated df
                'importance': mean_abs_shap
            }).sort_values(by='importance', ascending=False)
            
            print("\n--- SHAP Feature Importances (Mean Absolute SHAP Value) ---")
            print(feature_importances_shap)
            wandb.log({"shap_feature_importances": wandb.Table(dataframe=feature_importances_shap)})

# %%
# Jupyter Notebook Cell 2: Define Sweep Configuration
# Define the sweep configuration directly in Python
sweep_config = {
    'method': 'bayes',     # grid, random, or bayes
    'metric': {
        'name': 'global_overall_rmse',
        'goal': 'minimize'
    },
    'parameters': {
        # Fixed parameters (or parameters you don't want to sweep)
        'initial_train_months': {'value': 60},
        'test_window': {'value': 6},

        # Hyperparameters to sweep
        'n_estimators': {
            'distribution': 'int_uniform',
            'min': 50,
            'max': 300 
        },
        'learning_rate': {
            'distribution': 'uniform',
            'min': 0.01,
            'max': 0.2
        },
        'max_depth': {
            'distribution': 'int_uniform',
            'min': 3,
            'max': 7 
        },
        'subsample': {
            'distribution': 'uniform',
            'min': 0.6,
            'max': 1.0
        },
        'colsample_bytree': {
            'distribution': 'uniform',
            'min': 0.6,
            'max': 1.0
        },
        'min_child_weight': {'distribution': 'int_uniform', 'min': 1, 'max': 10},
        'gamma': {'distribution': 'uniform', 'min': 0, 'max': 5},
        'reg_alpha': {'distribution': 'uniform', 'min': 0, 'max': 1},
        'reg_lambda': {'distribution': 'uniform', 'min': 0, 'max': 1}
        }


    }

# %%
# --- Step A: Initialize the sweep (requires brief internet connection) ---
n_runs = 100
print("Initializing sweep... (requires brief internet connection)")
sweep_id = wandb.sweep(sweep_config, project="dengue-indonesia-forecasting")
print(f"Sweep ID: {sweep_id}")

# --- Step B: Set WANDB settings ---
os.environ["WANDB_MODE"] = "online"
os.environ["WANDB_SILENT"] = "true"

# --- Step C: Run the sweep agent ---
print(f"Starting sweep agent for {n_runs} runs...")

wandb.agent(sweep_id, function=lambda: train(df.copy(), features_to_use=feat_list), count=n_runs)
print("\nSweep completed.")

# --- Step D: Post-Sweep Aggregation of SHAP Values ---
print("\nAggregating SHAP values from completed runs...")

# Replace these with your W&B entity and project
ENTITY = "patwuch"
PROJECT = "dengue-indonesia-forecasting"

api = wandb.Api()
runs = api.runs(f"{ENTITY}/{PROJECT}", filters={"sweep": sweep_id, "state": "finished"})

all_shap = []
all_X = []

for run in runs:
    try:
        artifact = run.use_artifact("shap_data:latest")
        artifact_dir = artifact.download()
        shap_values = np.load(os.path.join(artifact_dir, "shap_values.npy"))
        X_test = pd.read_csv(os.path.join(artifact_dir, "X_test_for_shap.csv"))

        all_shap.append(shap_values)
        all_X.append(X_test)

    except Exception as e:
        print(f"Skipping run {run.name} due to error: {e}")

if all_shap and all_X:
    print("Generating global SHAP summary plot...")
    global_shap = np.vstack(all_shap)
    global_X = pd.concat(all_X, axis=0)

    shap.summary_plot(global_shap, global_X, show=True)  # Set show=False to save instead of display
else:
    print("No SHAP data found across runs. Global SHAP summary plot will not be created.")
# Out:
# Initializing sweep... (requires brief internet connection)
# Create sweep with ID: v1od5edv
# Sweep URL: https://wandb.ai/patwuch/dengue-indonesia-forecasting/sweeps/v1od5edv
# Sweep ID: v1od5edv
# Starting sweep agent for 100 runs...
# wandb: Agent Starting Run: b2qmkxig with config:
# wandb: 	colsample_bytree: 0.9559386009734128
# wandb: 	gamma: 2.0491539412770625
# wandb: 	initial_train_months: 60
# wandb: 	learning_rate: 0.08582174294963511
# wandb: 	max_depth: 4
# wandb: 	min_child_weight: 6
# wandb: 	n_estimators: 227
# wandb: 	reg_alpha: 0.9417852428306468
# wandb: 	reg_lambda: 0.42773839764950594
# wandb: 	subsample: 0.8535256350043774
# wandb: 	test_window: 6
# --- Starting run with config: {'colsample_bytree': 0.9559386009734128, 'gamma': 2.0491539412770625, 'initial_train_months': 60, 'learning_rate': 0.08582174294963511, 'max_depth': 4, 'min_child_weight': 6, 'n_estimators': 227, 'reg_alpha': 0.9417852428306468, 'reg_lambda': 0.42773839764950594, 'subsample': 0.8535256350043774, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.79, MAE=0.55
#     Fold 2/179: RMSE=0.85, MAE=0.57
#     Fold 3/179: RMSE=0.72, MAE=0.55
#     Fold 4/179: RMSE=2.09, MAE=1.10
#     Fold 5/179: RMSE=2.98, MAE=1.63
#     Fold 6/179: RMSE=1.03, MAE=0.61
#     Fold 7/179: RMSE=1.03, MAE=0.89
#     Fold 8/179: RMSE=0.81, MAE=0.58
#     Fold 9/179: RMSE=1.40, MAE=0.98
#     Fold 10/179: RMSE=1.38, MAE=1.05
#     Fold 11/179: RMSE=2.38, MAE=1.77
#     Fold 12/179: RMSE=2.53, MAE=1.67
#     Fold 13/179: RMSE=3.02, MAE=2.20
#     Fold 14/179: RMSE=2.56, MAE=1.93
#     Fold 15/179: RMSE=1.14, MAE=0.95
#     Fold 16/179: RMSE=0.82, MAE=0.69
#     Fold 17/179: RMSE=0.49, MAE=0.43
#     Fold 18/179: RMSE=1.33, MAE=1.19
#     Fold 19/179: RMSE=0.77, MAE=0.54
#     Fold 20/179: RMSE=0.47, MAE=0.41
#     Fold 21/179: RMSE=0.72, MAE=0.56
#     Fold 22/179: RMSE=1.63, MAE=1.08
#     Fold 23/179: RMSE=1.36, MAE=0.97
#     Fold 24/179: RMSE=1.45, MAE=0.96
#     Fold 25/179: RMSE=2.44, MAE=1.97
#     Fold 140/179: RMSE=2.12, MAE=1.46
#     Fold 141/179: RMSE=0.97, MAE=0.87
#     Fold 142/179: RMSE=1.05, MAE=0.92
#     Fold 143/179: RMSE=1.25, MAE=1.09
#     Fold 144/179: RMSE=0.81, MAE=0.62
#     Fold 145/179: RMSE=0.89, MAE=0.75
#     Fold 146/179: RMSE=0.73, MAE=0.65
#     Fold 147/179: RMSE=0.85, MAE=0.80
#     Fold 148/179: RMSE=0.98, MAE=0.75
#     Fold 149/179: RMSE=0.89, MAE=0.72
#     Fold 150/179: RMSE=1.98, MAE=1.70
#     Fold 151/179: RMSE=1.46, MAE=1.29
#     Fold 152/179: RMSE=10.89, MAE=9.51
#     Fold 153/179: RMSE=7.97, MAE=7.04
#     Fold 154/179: RMSE=3.58, MAE=3.33
#     Fold 155/179: RMSE=1.18, MAE=1.03
#     Fold 156/179: RMSE=1.27, MAE=1.09
#     Fold 157/179: RMSE=1.68, MAE=1.36
#     Fold 158/179: RMSE=1.54, MAE=1.12
#     Fold 159/179: RMSE=2.35, MAE=1.99
#     Fold 160/179: RMSE=1.26, MAE=1.19
#     Fold 161/179: RMSE=1.38, MAE=1.06
#     Fold 162/179: RMSE=0.95, MAE=0.71
#     Fold 163/179: RMSE=1.63, MAE=0.90
#     Fold 164/179: RMSE=1.13, MAE=0.87
#     Fold 165/179: RMSE=2.12, MAE=1.53
#     Fold 166/179: RMSE=5.51, MAE=4.05
#     Fold 167/179: RMSE=11.40, MAE=6.97
#     Fold 168/179: RMSE=12.35, MAE=7.44
#     Fold 169/179: RMSE=1.45, MAE=1.25
#     Fold 170/179: RMSE=8.69, MAE=4.34
#     Fold 171/179: RMSE=6.64, MAE=3.24
#     Fold 172/179: RMSE=2.08, MAE=1.32
#     Fold 173/179: RMSE=1.58, MAE=1.31
#     Fold 174/179: RMSE=1.75, MAE=1.35
#     Fold 175/179: RMSE=1.98, MAE=1.59
#     Fold 176/179: RMSE=2.29, MAE=1.55
#     Fold 177/179: RMSE=3.16, MAE=1.89
#     Fold 178/179: RMSE=1.21, MAE=1.01
#     Fold 179/179: RMSE=2.54, MAE=2.03
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.14, MAE=1.64 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 15                    Class_60    0.469907
# 39  total_evaporation_sum_lag1    0.446758
# 40  total_evaporation_sum_lag2    0.327120
# 55                  ANOM4_lag3    0.212756
# 16                    Class_50    0.189318
# ..                         ...         ...
# 19                    Class_30    0.008663
# 23                    Class_80    0.003539
# 21                    Class_10    0.001619
# 17                    Class_40    0.000979
# 14                    Class_70    0.000822
#
# [66 rows x 2 columns]
#
# --- Starting run with config: {'colsample_bytree': 0.900929366072853, 'gamma': 1.4894538464328866, 'initial_train_months': 60, 'learning_rate': 0.10514918146303263, 'max_depth': 4, 'min_child_weight': 10, 'n_estimators': 210, 'reg_alpha': 0.05978194085247013, 'reg_lambda': 0.7504818450571505, 'subsample': 0.9329486354582556, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.79, MAE=0.55
#     Fold 2/179: RMSE=0.85, MAE=0.57
#     Fold 3/179: RMSE=0.70, MAE=0.52
#     Fold 4/179: RMSE=2.48, MAE=1.20
#     Fold 5/179: RMSE=3.37, MAE=1.79
#     Fold 6/179: RMSE=1.03, MAE=0.61
#     Fold 7/179: RMSE=0.83, MAE=0.73
#     Fold 8/179: RMSE=0.81, MAE=0.58
#     Fold 9/179: RMSE=1.38, MAE=0.91
#     Fold 10/179: RMSE=1.31, MAE=0.89
#     Fold 11/179: RMSE=2.70, MAE=2.10
#     Fold 12/179: RMSE=2.90, MAE=1.84
#     Fold 13/179: RMSE=3.02, MAE=2.20
#     Fold 14/179: RMSE=2.46, MAE=1.93
#     Fold 15/179: RMSE=1.14, MAE=0.95
#     Fold 16/179: RMSE=0.82, MAE=0.69
#     Fold 17/179: RMSE=0.65, MAE=0.60
#     Fold 18/179: RMSE=1.13, MAE=1.02
#     Fold 19/179: RMSE=0.91, MAE=0.71
#     Fold 20/179: RMSE=0.41, MAE=0.36
#     Fold 21/179: RMSE=0.98, MAE=0.72
#     Fold 22/179: RMSE=1.63, MAE=1.08
#     Fold 23/179: RMSE=1.33, MAE=0.89
#     Fold 24/179: RMSE=1.45, MAE=0.96
#     Fold 25/179: RMSE=2.64, MAE=1.97
#     Fold 26/179: RMSE=3.66, MAE=3.18
#     Fold 27/179: RMSE=0.98, MAE=0.87
#     Fold 28/179: RMSE=1.01, MAE=0.72
#     Fold 144/179: RMSE=1.19, MAE=0.92
#     Fold 145/179: RMSE=1.39, MAE=1.08
#     Fold 146/179: RMSE=0.60, MAE=0.49
#     Fold 147/179: RMSE=1.14, MAE=0.96
#     Fold 148/179: RMSE=0.92, MAE=0.75
#     Fold 149/179: RMSE=1.30, MAE=1.06
#     Fold 150/179: RMSE=2.09, MAE=1.87
#     Fold 151/179: RMSE=1.53, MAE=1.45
#     Fold 152/179: RMSE=11.09, MAE=9.68
#     Fold 153/179: RMSE=8.00, MAE=7.04
#     Fold 154/179: RMSE=4.20, MAE=3.83
#     Fold 155/179: RMSE=1.62, MAE=1.53
#     Fold 156/179: RMSE=1.65, MAE=1.51
#     Fold 157/179: RMSE=2.15, MAE=1.69
#     Fold 158/179: RMSE=1.62, MAE=1.28
#     Fold 159/179: RMSE=2.19, MAE=1.83
#     Fold 160/179: RMSE=1.42, MAE=1.36
#     Fold 161/179: RMSE=1.45, MAE=1.19
#     Fold 162/179: RMSE=0.63, MAE=0.55
#     Fold 163/179: RMSE=1.69, MAE=1.18
#     Fold 164/179: RMSE=0.62, MAE=0.54
#     Fold 165/179: RMSE=2.24, MAE=1.57
#     Fold 166/179: RMSE=5.76, MAE=4.38
#     Fold 167/179: RMSE=10.86, MAE=6.47
#     Fold 168/179: RMSE=12.44, MAE=7.78
#     Fold 169/179: RMSE=1.58, MAE=1.17
#     Fold 170/179: RMSE=9.51, MAE=4.74
#     Fold 171/179: RMSE=6.24, MAE=3.24
#     Fold 172/179: RMSE=1.81, MAE=1.32
#     Fold 173/179: RMSE=1.02, MAE=0.81
#     Fold 174/179: RMSE=2.48, MAE=1.62
#     Fold 175/179: RMSE=1.70, MAE=1.43
#     Fold 176/179: RMSE=1.78, MAE=1.14
#     Fold 177/179: RMSE=3.02, MAE=1.73
#     Fold 178/179: RMSE=1.22, MAE=0.86
#     Fold 179/179: RMSE=3.01, MAE=2.24
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.18, MAE=1.70 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 15                    Class_60    0.477640
# 39  total_evaporation_sum_lag1    0.465238
# 40  total_evaporation_sum_lag2    0.319719
# 55                  ANOM4_lag3    0.212477
# 13                    DMI_East    0.171082
# ..                         ...         ...
# 57                ANOM3.4_lag1    0.019013
# 19                    Class_30    0.009330
# 21                    Class_10    0.004194
# 23                    Class_80    0.003996
# 14                    Class_70    0.001074
#
# [66 rows x 2 columns]
#
# --- Starting run with config: {'colsample_bytree': 0.6313514346571296, 'gamma': 3.174725958671878, 'initial_train_months': 60, 'learning_rate': 0.1315970801396432, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 256, 'reg_alpha': 0.7379143340808908, 'reg_lambda': 0.1868380101370012, 'subsample': 0.980733833818684, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.79, MAE=0.55
#     Fold 2/179: RMSE=0.85, MAE=0.57
#     Fold 3/179: RMSE=0.95, MAE=0.55
#     Fold 4/179: RMSE=2.09, MAE=1.10
#     Fold 5/179: RMSE=2.88, MAE=1.46
#     Fold 6/179: RMSE=1.03, MAE=0.61
#     Fold 7/179: RMSE=1.02, MAE=0.89
#     Fold 8/179: RMSE=0.81, MAE=0.58
#     Fold 9/179: RMSE=1.17, MAE=0.75
#     Fold 10/179: RMSE=1.31, MAE=0.89
#     Fold 11/179: RMSE=2.70, MAE=2.10
#     Fold 12/179: RMSE=2.53, MAE=1.67
#     Fold 13/179: RMSE=3.28, MAE=2.37
#     Fold 14/179: RMSE=2.41, MAE=1.76
#     Fold 15/179: RMSE=1.14, MAE=0.95
#     Fold 16/179: RMSE=0.90, MAE=0.82
#     Fold 17/179: RMSE=0.60, MAE=0.54
#     Fold 18/179: RMSE=1.61, MAE=1.36
#     Fold 19/179: RMSE=0.85, MAE=0.68
#     Fold 20/179: RMSE=0.41, MAE=0.36
#     Fold 21/179: RMSE=0.74, MAE=0.59
#     Fold 22/179: RMSE=1.63, MAE=1.08
#     Fold 23/179: RMSE=1.34, MAE=0.90
#     Fold 24/179: RMSE=1.45, MAE=0.96
#     Fold 25/179: RMSE=2.04, MAE=1.47
#     Fold 26/179: RMSE=3.52, MAE=3.18
#     Fold 27/179: RMSE=0.98, MAE=0.87
#     Fold 28/179: RMSE=1.17, MAE=1.03
#     Fold 29/179: RMSE=1.37, MAE=1.14
#     Fold 30/179: RMSE=1.94, MAE=1.56
#     Fold 31/179: RMSE=1.02, MAE=0.87
#     Fold 32/179: RMSE=0.90, MAE=0.74
#     Fold 33/179: RMSE=1.08, MAE=0.74
#     Fold 148/179: RMSE=0.86, MAE=0.70
#     Fold 149/179: RMSE=1.25, MAE=0.91
#     Fold 150/179: RMSE=2.10, MAE=1.92
#     Fold 151/179: RMSE=1.26, MAE=1.09
#     Fold 152/179: RMSE=10.86, MAE=9.51
#     Fold 153/179: RMSE=8.04, MAE=7.21
#     Fold 154/179: RMSE=3.79, MAE=3.32
#     Fold 155/179: RMSE=1.05, MAE=0.92
#     Fold 156/179: RMSE=2.03, MAE=1.68
#     Fold 157/179: RMSE=2.20, MAE=1.86
#     Fold 158/179: RMSE=1.61, MAE=1.28
#     Fold 159/179: RMSE=2.14, MAE=1.83
#     Fold 160/179: RMSE=1.86, MAE=1.69
#     Fold 161/179: RMSE=1.15, MAE=1.02
#     Fold 162/179: RMSE=0.88, MAE=0.72
#     Fold 163/179: RMSE=2.05, MAE=1.19
#     Fold 164/179: RMSE=1.13, MAE=0.87
#     Fold 165/179: RMSE=2.20, MAE=1.36
#     Fold 166/179: RMSE=5.18, MAE=3.75
#     Fold 167/179: RMSE=10.96, MAE=6.63
#     Fold 168/179: RMSE=11.90, MAE=7.11
#     Fold 169/179: RMSE=1.51, MAE=1.29
#     Fold 170/179: RMSE=9.06, MAE=4.40
#     Fold 171/179: RMSE=6.67, MAE=3.40
#     Fold 172/179: RMSE=2.03, MAE=1.60
#     Fold 173/179: RMSE=1.34, MAE=1.22
#     Fold 174/179: RMSE=1.82, MAE=1.45
#     Fold 175/179: RMSE=1.53, MAE=1.09
#     Fold 176/179: RMSE=1.36, MAE=0.88
#     Fold 177/179: RMSE=2.64, MAE=1.56
#     Fold 178/179: RMSE=1.28, MAE=1.01
#     Fold 179/179: RMSE=2.83, MAE=2.36
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.14, MAE=1.69 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 39  total_evaporation_sum_lag1    0.430905
# 15                    Class_60    0.334637
# 40  total_evaporation_sum_lag2    0.317106
# 55                  ANOM4_lag3    0.217697
# 5        total_evaporation_sum    0.161192
# ..                         ...         ...
# 20                    Class_20    0.021547
# 51                  ANOM3_lag1    0.020329
# 21                    Class_10    0.014242
# 23                    Class_80    0.007335
# 14                    Class_70    0.000851
#
# [66 rows x 2 columns]
#
# --- Starting run with config: {'colsample_bytree': 0.6218271095483454, 'gamma': 3.8168104158677663, 'initial_train_months': 60, 'learning_rate': 0.19044338577681705, 'max_depth': 5, 'min_child_weight': 2, 'n_estimators': 233, 'reg_alpha': 0.663025212655332, 'reg_lambda': 0.7875976280933158, 'subsample': 0.7050032836721167, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.80, MAE=0.56
#     Fold 2/179: RMSE=0.78, MAE=0.46
#     Fold 3/179: RMSE=0.83, MAE=0.73
#     Fold 4/179: RMSE=1.69, MAE=0.93
#     Fold 5/179: RMSE=3.00, MAE=1.75
#     Fold 6/179: RMSE=1.03, MAE=0.61
#     Fold 7/179: RMSE=0.80, MAE=0.69
#     Fold 8/179: RMSE=0.81, MAE=0.58
#     Fold 9/179: RMSE=1.38, MAE=0.91
#     Fold 10/179: RMSE=1.19, MAE=0.72
#     Fold 11/179: RMSE=2.64, MAE=1.94
#     Fold 12/179: RMSE=2.59, MAE=1.84
#     Fold 13/179: RMSE=2.62, MAE=1.87
#     Fold 14/179: RMSE=2.43, MAE=1.93
#     Fold 15/179: RMSE=1.94, MAE=1.40
#     Fold 16/179: RMSE=0.82, MAE=0.69
#     Fold 17/179: RMSE=0.90, MAE=0.77
#     Fold 18/179: RMSE=1.33, MAE=1.19
#     Fold 19/179: RMSE=0.83, MAE=0.63
#     Fold 20/179: RMSE=0.65, MAE=0.58
#     Fold 21/179: RMSE=0.66, MAE=0.48
#     Fold 22/179: RMSE=1.63, MAE=1.08
#     Fold 23/179: RMSE=1.69, MAE=1.05
#     Fold 24/179: RMSE=1.60, MAE=1.12
#     Fold 25/179: RMSE=2.21, MAE=1.37
#     Fold 26/179: RMSE=3.52, MAE=3.18
#     Fold 27/179: RMSE=1.11, MAE=1.01
#     Fold 28/179: RMSE=0.76, MAE=0.61
#     Fold 29/179: RMSE=1.45, MAE=1.31
#     Fold 30/179: RMSE=1.89, MAE=1.65
#     Fold 31/179: RMSE=1.93, MAE=1.54
#     Fold 32/179: RMSE=0.92, MAE=0.70
#     Fold 33/179: RMSE=1.50, MAE=1.03
#     Fold 34/179: RMSE=0.41, MAE=0.31
#     Fold 35/179: RMSE=0.96, MAE=0.80
#     Fold 36/179: RMSE=0.55, MAE=0.43
#     Fold 152/179: RMSE=11.33, MAE=9.84
#     Fold 153/179: RMSE=8.00, MAE=6.54
#     Fold 154/179: RMSE=3.06, MAE=2.82
#     Fold 155/179: RMSE=1.67, MAE=1.26
#     Fold 156/179: RMSE=2.38, MAE=2.14
#     Fold 157/179: RMSE=1.26, MAE=0.99
#     Fold 158/179: RMSE=2.01, MAE=1.62
#     Fold 159/179: RMSE=2.15, MAE=1.99
#     Fold 160/179: RMSE=1.63, MAE=1.44
#     Fold 161/179: RMSE=1.65, MAE=1.40
#     Fold 162/179: RMSE=0.72, MAE=0.65
#     Fold 163/179: RMSE=2.11, MAE=1.40
#     Fold 164/179: RMSE=1.37, MAE=1.12
#     Fold 165/179: RMSE=2.44, MAE=1.70
#     Fold 166/179: RMSE=5.43, MAE=4.38
#     Fold 167/179: RMSE=10.46, MAE=6.13
#     Fold 168/179: RMSE=12.45, MAE=7.78
#     Fold 169/179: RMSE=1.98, MAE=1.82
#     Fold 170/179: RMSE=9.59, MAE=5.00
#     Fold 171/179: RMSE=6.64, MAE=3.24
#     Fold 172/179: RMSE=2.86, MAE=1.66
#     Fold 173/179: RMSE=1.99, MAE=1.72
#     Fold 174/179: RMSE=2.26, MAE=1.95
#     Fold 175/179: RMSE=1.39, MAE=1.04
#     Fold 176/179: RMSE=2.48, MAE=1.88
#     Fold 177/179: RMSE=2.78, MAE=1.99
#     Fold 178/179: RMSE=1.83, MAE=1.19
#     Fold 179/179: RMSE=4.76, MAE=3.53
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.17, MAE=1.70 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 39  total_evaporation_sum_lag1    0.432667
# 15                    Class_60    0.365465
# 55                  ANOM4_lag3    0.211335
# 40  total_evaporation_sum_lag2    0.203058
# 5        total_evaporation_sum    0.165749
# ..                         ...         ...
# 51                  ANOM3_lag1    0.031009
# 22                    Class_90    0.016240
# 21                    Class_10    0.015543
# 23                    Class_80    0.013105
# 14                    Class_70    0.002519
#
# [66 rows x 2 columns]
#
# --- Starting run with config: {'colsample_bytree': 0.9569107032840862, 'gamma': 1.515052726897924, 'initial_train_months': 60, 'learning_rate': 0.17406234473603138, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 78, 'reg_alpha': 0.3206252518055298, 'reg_lambda': 0.5253877280356625, 'subsample': 0.8629096076657405, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.68, MAE=0.40
#     Fold 2/179: RMSE=0.85, MAE=0.57
#     Fold 3/179: RMSE=0.80, MAE=0.67
#     Fold 4/179: RMSE=2.09, MAE=1.10
#     Fold 5/179: RMSE=2.59, MAE=1.49
#     Fold 6/179: RMSE=1.51, MAE=0.94
#     Fold 7/179: RMSE=0.91, MAE=0.87
#     Fold 8/179: RMSE=0.65, MAE=0.42
#     Fold 9/179: RMSE=1.17, MAE=0.75
#     Fold 10/179: RMSE=1.19, MAE=0.72
#     Fold 11/179: RMSE=2.44, MAE=1.94
#     Fold 12/179: RMSE=2.38, MAE=1.51
#     Fold 13/179: RMSE=3.42, MAE=2.54
#     Fold 14/179: RMSE=2.36, MAE=1.93
#     Fold 15/179: RMSE=1.28, MAE=1.12
#     Fold 16/179: RMSE=1.15, MAE=0.86
#     Fold 17/179: RMSE=0.90, MAE=0.77
#     Fold 18/179: RMSE=0.93, MAE=0.69
#     Fold 19/179: RMSE=0.77, MAE=0.54
#     Fold 20/179: RMSE=0.66, MAE=0.53
#     Fold 21/179: RMSE=0.66, MAE=0.48
#     Fold 22/179: RMSE=1.63, MAE=1.08
#     Fold 23/179: RMSE=1.39, MAE=1.04
#     Fold 24/179: RMSE=1.55, MAE=1.25
#     Fold 25/179: RMSE=2.74, MAE=2.14
#     Fold 26/179: RMSE=3.24, MAE=2.84
#     Fold 27/179: RMSE=1.54, MAE=1.34
#     Fold 28/179: RMSE=1.22, MAE=1.05
#     Fold 29/179: RMSE=1.17, MAE=0.89
#     Fold 30/179: RMSE=2.62, MAE=2.06
#     Fold 31/179: RMSE=1.02, MAE=0.87
#     Fold 32/179: RMSE=0.92, MAE=0.76
#     Fold 33/179: RMSE=1.08, MAE=0.74
#     Fold 34/179: RMSE=0.64, MAE=0.48
#     Fold 35/179: RMSE=1.30, MAE=1.02
#     Fold 36/179: RMSE=0.91, MAE=0.60
#     Fold 37/179: RMSE=1.13, MAE=0.78
#     Fold 38/179: RMSE=1.10, MAE=0.77
#     Fold 39/179: RMSE=0.94, MAE=0.80
#     Fold 40/179: RMSE=2.07, MAE=1.84
#     Fold 156/179: RMSE=2.09, MAE=1.55
#     Fold 157/179: RMSE=2.37, MAE=1.92
#     Fold 158/179: RMSE=1.92, MAE=1.28
#     Fold 159/179: RMSE=2.93, MAE=2.43
#     Fold 160/179: RMSE=1.51, MAE=1.36
#     Fold 161/179: RMSE=1.46, MAE=1.23
#     Fold 162/179: RMSE=0.63, MAE=0.55
#     Fold 163/179: RMSE=1.57, MAE=1.23
#     Fold 164/179: RMSE=2.43, MAE=1.65
#     Fold 165/179: RMSE=2.51, MAE=1.86
#     Fold 166/179: RMSE=5.95, MAE=4.29
#     Fold 167/179: RMSE=10.50, MAE=6.30
#     Fold 168/179: RMSE=12.00, MAE=7.44
#     Fold 169/179: RMSE=1.82, MAE=1.49
#     Fold 170/179: RMSE=8.81, MAE=4.74
#     Fold 171/179: RMSE=6.62, MAE=3.17
#     Fold 172/179: RMSE=2.73, MAE=2.27
#     Fold 173/179: RMSE=2.23, MAE=1.89
#     Fold 174/179: RMSE=2.10, MAE=1.45
#     Fold 175/179: RMSE=1.86, MAE=1.43
#     Fold 176/179: RMSE=2.24, MAE=1.38
#     Fold 177/179: RMSE=2.64, MAE=1.58
#     Fold 178/179: RMSE=0.93, MAE=0.74
#     Fold 179/179: RMSE=3.12, MAE=2.24
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.28, MAE=1.74 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 39  total_evaporation_sum_lag1    0.491314
# 15                    Class_60    0.449758
# 40  total_evaporation_sum_lag2    0.275575
# 16                    Class_50    0.247589
# 55                  ANOM4_lag3    0.208201
# ..                         ...         ...
# 19                    Class_30    0.002827
# 23                    Class_80    0.002586
# 21                    Class_10    0.000726
# 14                    Class_70    0.000514
# 17                    Class_40    0.000026
#
# [66 rows x 2 columns]
#
# --- Starting run with config: {'colsample_bytree': 0.6736355977545283, 'gamma': 2.8906386931856427, 'initial_train_months': 60, 'learning_rate': 0.12991792763098872, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 256, 'reg_alpha': 0.8002907492491284, 'reg_lambda': 0.07594805278975048, 'subsample': 0.9605889919658548, 'test_window': 6} ---
# Features selected for training: ['temperature_2m', 'temperature_2m_min', 'temperature_2m_max', 'precipitation', 'potential_evaporation_sum', 'total_evaporation_sum', 'evaporative_stress_index', 'aridity_index', 'ANOM1+2', 'ANOM3', 'ANOM4', 'ANOM3.4', 'DMI', 'DMI_East', 'Class_70', 'Class_60', 'Class_50', 'Class_40', 'Class_95', 'Class_30', 'Class_20', 'Class_10', 'Class_90', 'Class_80', 'temperature_2m_lag1', 'temperature_2m_lag2', 'temperature_2m_lag3', 'temperature_2m_min_lag1', 'temperature_2m_min_lag2', 'temperature_2m_min_lag3', 'temperature_2m_max_lag1', 'temperature_2m_max_lag2', 'temperature_2m_max_lag3', 'precipitation_lag1', 'precipitation_lag2', 'precipitation_lag3', 'potential_evaporation_sum_lag1', 'potential_evaporation_sum_lag2', 'potential_evaporation_sum_lag3', 'total_evaporation_sum_lag1', 'total_evaporation_sum_lag2', 'total_evaporation_sum_lag3', 'evaporative_stress_index_lag1', 'evaporative_stress_index_lag2', 'evaporative_stress_index_lag3', 'aridity_index_lag1', 'aridity_index_lag2', 'aridity_index_lag3', 'ANOM1+2_lag1', 'ANOM1+2_lag3', 'ANOM1+2_lag6', 'ANOM3_lag1', 'ANOM3_lag3', 'ANOM3_lag6', 'ANOM4_lag1', 'ANOM4_lag3', 'ANOM4_lag6', 'ANOM3.4_lag1', 'ANOM3.4_lag3', 'ANOM3.4_lag6', 'DMI_lag1', 'DMI_lag3', 'DMI_lag6', 'DMI_East_lag1', 'DMI_East_lag3', 'DMI_East_lag6']
# Performing 179 walk-forward splits on combined data...
#     Fold 1/179: RMSE=0.88, MAE=0.71
#     Fold 2/179: RMSE=0.53, MAE=0.41
#     Fold 3/179: RMSE=1.46, MAE=1.03
#     Fold 4/179: RMSE=1.69, MAE=0.93
#     Fold 5/179: RMSE=2.22, MAE=1.32
#     Fold 6/179: RMSE=1.42, MAE=0.77
# ...
#     Fold 26/179: RMSE=3.92, MAE=3.51
#     Fold 27/179: RMSE=1.59, MAE=1.47
#     Fold 28/179: RMSE=1.08, MAE=0.89
#     Fold 29/179: RMSE=1.44, MAE=1.31
#     Fold 30/179: RMSE=2.05, MAE=1.73
#     Fold 31/179: RMSE=1.73, MAE=1.21
#     Fold 32/179: RMSE=0.90, MAE=0.74
#     Fold 33/179: RMSE=1.59, MAE=1.07
#     Fold 34/179: RMSE=0.62, MAE=0.48
#     Fold 35/179: RMSE=0.99, MAE=0.85
#     Fold 36/179: RMSE=0.55, MAE=0.43
#     Fold 37/179: RMSE=0.66, MAE=0.44
#     Fold 38/179: RMSE=1.10, MAE=0.77
#     Fold 39/179: RMSE=1.20, MAE=0.97
#     Fold 40/179: RMSE=2.17, MAE=1.72
#     Fold 41/179: RMSE=1.91, MAE=1.41
#     Fold 42/179: RMSE=1.48, MAE=1.29
#     Fold 43/179: RMSE=0.91, MAE=0.80
#     Fold 44/179: RMSE=1.57, MAE=1.24
#     Fold 45/179: RMSE=1.50, MAE=0.98
#     Fold 46/179: RMSE=2.06, MAE=1.40
#     Fold 47/179: RMSE=1.62, MAE=1.38
#     Fold 48/179: RMSE=1.57, MAE=1.24
#     Fold 49/179: RMSE=1.49, MAE=0.89
#     Fold 50/179: RMSE=2.66, MAE=1.68
#     Fold 51/179: RMSE=2.98, MAE=1.97
#     Fold 52/179: RMSE=0.86, MAE=0.76
#     Fold 53/179: RMSE=4.59, MAE=3.02
#     Fold 54/179: RMSE=6.40, MAE=4.41
#     Fold 55/179: RMSE=5.18, MAE=3.83
#     Fold 56/179: RMSE=1.35, MAE=1.06
#     Fold 57/179: RMSE=1.36, MAE=1.14
#     Fold 58/179: RMSE=2.49, MAE=2.12
#     Fold 59/179: RMSE=0.84, MAE=0.75
#     Fold 60/179: RMSE=1.47, MAE=1.35
#     Fold 61/179: RMSE=0.85, MAE=0.59
#     Fold 62/179: RMSE=0.62, MAE=0.54
#     Fold 63/179: RMSE=1.26, MAE=0.89
#     Fold 64/179: RMSE=1.68, MAE=1.23
#     Fold 179/179: RMSE=2.70, MAE=2.03
#
# --- GLOBAL Overall Walk-Forward Evaluation: RMSE=3.20, MAE=1.70 ---
#
# --- SHAP Feature Importances (Mean Absolute SHAP Value) ---
#                        feature  importance
# 39  total_evaporation_sum_lag1    0.376052
# 15                    Class_60    0.357957
# 40  total_evaporation_sum_lag2    0.249401
# 55                  ANOM4_lag3    0.185238
# 50                ANOM1+2_lag6    0.153997
# ..                         ...         ...
# 31     temperature_2m_max_lag2    0.009906
# 27     temperature_2m_min_lag1    0.008937
# 49                ANOM1+2_lag3    0.008636
# 23                    Class_80    0.001902
# 14                    Class_70    0.000060
#
# [66 rows x 2 columns]
#
# Sweep completed.
#
# Aggregating SHAP values from completed runs...
# Skipping run deft-sweep-1 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run vocal-sweep-2 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run smooth-sweep-3 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run electric-sweep-4 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run good-sweep-5 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run visionary-sweep-6 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run rose-sweep-7 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run distinctive-sweep-8 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run youthful-sweep-9 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run cool-sweep-10 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run gentle-sweep-11 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run clear-sweep-12 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run classic-sweep-13 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run light-sweep-14 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run dazzling-sweep-15 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run earthy-sweep-16 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run spring-sweep-17 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run leafy-sweep-18 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run flowing-sweep-19 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run comic-sweep-20 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run summer-sweep-21 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fiery-sweep-22 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fiery-sweep-23 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run lively-sweep-24 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run apricot-sweep-25 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run scarlet-sweep-26 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run cool-sweep-27 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run olive-sweep-28 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run decent-sweep-29 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run legendary-sweep-30 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run breezy-sweep-31 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run lilac-sweep-32 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run deft-sweep-33 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run trim-sweep-34 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run misty-sweep-35 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run still-sweep-36 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run smooth-sweep-37 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run swift-sweep-38 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run rosy-sweep-39 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run classic-sweep-40 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run winter-sweep-41 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run vivid-sweep-42 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run floral-sweep-43 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run treasured-sweep-44 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run wild-sweep-45 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run prime-sweep-46 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fast-sweep-47 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run charmed-sweep-48 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run deep-sweep-49 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run dazzling-sweep-50 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run volcanic-sweep-51 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run azure-sweep-54 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run royal-sweep-57 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fanciful-sweep-58 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fluent-sweep-59 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run peachy-sweep-60 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run playful-sweep-61 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run misty-sweep-62 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run bright-sweep-63 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fearless-sweep-64 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run clear-sweep-65 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run solar-sweep-66 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run stellar-sweep-67 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run sleek-sweep-68 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run amber-sweep-69 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run clean-sweep-70 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run dauntless-sweep-71 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fast-sweep-72 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run comfy-sweep-73 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run vivid-sweep-74 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run pleasant-sweep-75 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run icy-sweep-76 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run graceful-sweep-77 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run eager-sweep-78 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run copper-sweep-79 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run eager-sweep-80 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fancy-sweep-81 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run wise-sweep-82 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run azure-sweep-83 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fragrant-sweep-84 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fresh-sweep-85 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fluent-sweep-86 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run winter-sweep-87 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run good-sweep-88 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run giddy-sweep-89 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run cerulean-sweep-90 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run floral-sweep-91 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run misty-sweep-92 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run summer-sweep-93 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run worldly-sweep-94 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run iconic-sweep-95 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run dark-sweep-96 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run sparkling-sweep-97 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fine-sweep-98 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run fiery-sweep-99 due to error: You must pass a wandb.Api().artifact() to use_artifact
# Skipping run visionary-sweep-100 due to error: You must pass a wandb.Api().artifact() to use_artifact
# No SHAP data found across runs. Global SHAP summary plot will not be created.
